# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\hp\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\hp\anaconda3\lib\site-packages (from selenium) (1.25.9)

# %%
import selenium
from selenium import webdriver

# %%
driver=webdriver.Chrome("D:\\chromedriver_win32\\chromedriver.exe")

# %%
driver.close()

# %%
driver=webdriver.Chrome("D:\\chromedriver_win32\\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
#finding element for job search bar

search_sunglass= driver.find_element_by_xpath("//input[@type='text']")
search_sunglass.send_keys("sunglasses")

close_btn=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
close_btn.click()

# %%
search_btn=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
search_btn.click()

# %% [raw]
# #Now we need to create empty lists for 4 features
# 1.Brand 2.Product_desc 3.price 4.discount

# %%
Brand=[]
Product_desc=[]
price=[]
discount=[]

# %%
#Extract the tag having the brand-titles
brands_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
brands_tags[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="877e7299-d854-497d-a380-d0e048e54f9a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="5071a0a7-b862-4a56-af42-111ec7d7e9ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="d6815b78-08ec-457d-aea5-e7841676e559")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="cd4a6fd9-70e4-4e8a-b259-f9ab6a80f17d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="769ef346-a828-4eed-8d7f-c39b7bb9f27c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="85d70091-cb70-4f5b-8a69-876b576ec023")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="cfffb93e-1989-4484-9b5a-b5a4b0998842")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="38681890-b9ef-4125-a7d3-128b4c734985")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="bf4ad32c-8277-4f89-82c1-4fff58893202")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4c22a7fecb08da0e2aeee3bc511c8d5a", element="0f3a4b19-4afd-4b47-a25e-cde3f9dd06c9")>]

# %%
#Extract the tag having the brand-titles

for page in range(0,3):
    brands_tags=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
    
for i in brands_tags:
    brands=i.text
    Brand.append(brands)
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
Brand[0:100]
# Out:
# ['hipe',
#  'Ayezent',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Phenomenal',
#  'PIRASO',
#  'Phenomenal',
#  'Elligator',
#  'shah collections',
#  'Rozzetta Craft',
#  'Royal Son',
#  'Fastrack',
#  'shah collections',
#  'Online Mantra',
#  'Fastrack',
#  'kingsunglasses',
#  'ROYAL SON',
#  'Fastrack',
#  'funglasses',
#  'Fastrack',
#  'ROYAL SON',
#  'Rex',
#  'JUST STYLE',
#  'Fastrack',
#  'Riffko',
#  'funglasses',
#  'hipe',
#  'Gansta',
#  'Deixels',
#  'ETRG',
#  'Royal Son',
#  'ROZZETTA CRAFT',
#  'EYELLUSION',
#  'PIRASO',
#  'funglasses',
#  'Fastrack',
#  'STYLE GURU',
#  'hipe',
#  'Royal Son',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Phenomenal',
#  'PIRASO',
#  'Phenomenal',
#  'Elligator',
#  'shah collections',
#  'Rozzetta Craft',
#  'ROYAL SON',
#  'Fastrack',
#  'shah collections',
#  'Online Mantra',
#  'Fastrack',
#  'kingsunglasses',
#  'ROYAL SON',
#  'Fastrack',
#  'funglasses',
#  'Fastrack',
#  'hipe',
#  'Rex',
#  'JUST STYLE',
#  'Fastrack',
#  'Riffko',
#  'funglasses',
#  'Royal Son',
#  'Gansta',
#  'Deixels',
#  'ETRG',
#  'STYLE GURU',
#  'ROZZETTA CRAFT',
#  'EYELLUSION',
#  'PIRASO',
#  'funglasses',
#  'Fastrack',
#  'ROYAL SON',
#  'hipe',
#  'Royal Son',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'Fastrack',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Phenomenal',
#  'PIRASO',
#  'Phenomenal',
#  'Elligator',
#  'shah collections',
#  'Rozzetta Craft',
#  'ROYAL SON',
#  'Fastrack',
#  'shah collections',
#  'Online Mantra',
#  'Fastrack',
#  'kingsunglasses',
#  'ROYAL SON']

# %%
#Extract the tag having the product_desc-titles

for page in range(0,3):
    products_tags=driver.find_elements_by_xpath("//a[@class='IRpwTa']")

    
for i in products_tags:
    products=i.text
    Product_desc.append(products)
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
Product_desc
# Out:
# ['UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Gradient, UV Protection Aviator Sunglasses (58)',
#  'UV Protection Rectangular Sunglasses (50)',
#  'UV Protection, Night Vision, Gradient Retro Square, Spe...',
#  'UV Protection Oval Sunglasses (56)',
#  'UV Protection Wayfarer Sunglasses (55)',
#  'Gradient, UV Protection Aviator, Retro Square Sunglasse...',
#  'UV Protection, Mirrored Retro Square Sunglasses (Free S...',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection, Riding Glasses Rectangular Sunglasses (F...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection, Night Vision, Riding Glasses, Polarized ...',
#  'UV Protection Wrap-around Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (58)',
#  'Gradient Spectacle Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'Mirrored, UV Protection Round Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (54)',
#  'UV Protection, Mirrored Retro Square Sunglasses (53)',
#  'Polarized Sports Sunglasses (70)',
#  'UV Protection, Polarized Wayfarer Sunglasses (56)',
#  'UV Protection, Polarized Aviator Sunglasses (Free Size)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'Polarized, UV Protection Retro Square Sunglasses (53)',
#  'UV Protection, Night Vision, Gradient Retro Square, Spe...',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Gradient, UV Protection Aviator Sunglasses (58)',
#  'Gradient, UV Protection Aviator, Retro Square Sunglasse...',
#  'UV Protection, Night Vision, Gradient Retro Square, Spe...',
#  'UV Protection Oval Sunglasses (56)',
#  'UV Protection Wayfarer Sunglasses (55)',
#  'UV Protection, Mirrored Retro Square Sunglasses (Free S...',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection, Night Vision, Riding Glasses, Polarized ...',
#  'UV Protection, Riding Glasses Rectangular Sunglasses (F...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (58)',
#  'UV Protection Wrap-around Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (Free Size)',
#  'Gradient Spectacle Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'Mirrored, UV Protection Round Sunglasses (Free Size)',
#  'Polarized Sports Sunglasses (70)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (54)',
#  'UV Protection, Mirrored Retro Square Sunglasses (53)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection, Polarized Wayfarer Sunglasses (56)',
#  'UV Protection, Polarized Aviator Sunglasses (Free Size)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'Polarized, UV Protection Retro Square Sunglasses (53)',
#  'UV Protection, Night Vision, Gradient Retro Square, Spe...',
#  'Others Round Sunglasses (49)',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Gradient, UV Protection Aviator Sunglasses (58)',
#  'UV Protection Rectangular Sunglasses (50)',
#  'UV Protection, Night Vision, Gradient Retro Square, Spe...',
#  'UV Protection Oval Sunglasses (56)',
#  'UV Protection Wayfarer Sunglasses (55)',
#  'UV Protection Retro Square Sunglasses (52)',
#  'UV Protection, Mirrored Retro Square Sunglasses (Free S...',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Rectangular Sunglasses (58)',
#  'UV Protection, Riding Glasses Rectangular Sunglasses (F...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (58)',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'Gradient, UV Protection Aviator, Retro Square Sunglasse...',
#  'UV Protection Wrap-around Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (Free Size)',
#  'Gradient Spectacle Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'Mirrored, UV Protection Round Sunglasses (Free Size)',
#  'UV Protection, Night Vision, Riding Glasses, Polarized ...',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Shield Sunglasses (54)',
#  'UV Protection, Mirrored Retro Square Sunglasses (53)',
#  'UV Protection Retro Square Sunglasses (58)',
#  'UV Protection, Polarized Wayfarer Sunglasses (56)',
#  'UV Protection, Polarized Aviator Sunglasses (Free Size)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'Polarized, UV Protection Retro Square Sunglasses (53)',
#  'UV Protection, Night Vision, Gradient Retro Square, Spe...',
#  'UV Protection, Mirrored, Riding Glasses, Night Vision R...',
#  'UV Protection Rectangular Sunglasses (50)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection, Gradient Rectangular Sunglasses (Free Si...',
#  'UV Protection, Mirrored Retro Square Sunglasses (53)',
#  'UV Protection Aviator Sunglasses (Free Size)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'UV Protection, Polarized, Mirrored Rectangular Sunglass...',
#  'UV Protection Rectangular Sunglasses (Free Size)',
#  'Mirrored Aviator Sunglasses (55)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Round Sunglasses (Free Size)',
#  'UV Protection Wayfarer Sunglasses (56)',
#  'Mirrored, UV Protection Wayfarer, Wayfarer, Wayfarer, W...',
#  'UV Protection Retro Square Sunglasses (88)',
#  'UV Protection Aviator Sunglasses (58)',
#  'Mirrored, UV Protection Wayfarer Sunglasses (Free Size)',
#  'Mirrored, UV Protection, Others Wayfarer Sunglasses (32...',
#  'Gradient, UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (57)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'Gradient, UV Protection Aviator Sunglasses (99)',
#  'UV Protection Retro Square Sunglasses (Free Size)',
#  'Night Vision, Polarized, UV Protection, Riding Glasses ...',
#  'UV Protection Aviator Sunglasses (54)',
#  'UV Protection Wayfarer Sunglasses (Free Size)',
#  'UV Protection Aviator Sunglasses (Free Size)']

# %%
#Extract the tag having the price titles

for page in range(0,3):
    prices_tags=driver.find_elements_by_xpath("//div[@class='_30jeq3']")

    
for i in prices_tags:
    prices=i.text
    price.append(prices)
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
price
# Out:
# ['₹199',
#  '₹282',
#  '₹499',
#  '₹599',
#  '₹499',
#  '₹499',
#  '₹404',
#  '₹399',
#  '₹314',
#  '₹399',
#  '₹329',
#  '₹227',
#  '₹398',
#  '₹379',
#  '₹599',
#  '₹331',
#  '₹151',
#  '₹599',
#  '₹284',
#  '₹599',
#  '₹896',
#  '₹161',
#  '₹549',
#  '₹854',
#  '₹259',
#  '₹135',
#  '₹596',
#  '₹210',
#  '₹160',
#  '₹175',
#  '₹284',
#  '₹211',
#  '₹209',
#  '₹664',
#  '₹499',
#  '₹344',
#  '₹225',
#  '₹118',
#  '₹399',
#  '₹799',
#  '₹225',
#  '₹195',
#  '₹185',
#  '₹474',
#  '₹399',
#  '₹123',
#  '₹265',
#  '₹279',
#  '₹181',
#  '₹499',
#  '₹399',
#  '₹198',
#  '₹315',
#  '₹664',
#  '₹426',
#  '₹169',
#  '₹349',
#  '₹165',
#  '₹695',
#  '₹375',
#  '₹149',
#  '₹208',
#  '₹649',
#  '₹499',
#  '₹208',
#  '₹268',
#  '₹289',
#  '₹190',
#  '₹399',
#  '₹449',
#  '₹324',
#  '₹499',
#  '₹399',
#  '₹891',
#  '₹599',
#  '₹189',
#  '₹599',
#  '₹269',
#  '₹259',
#  '₹799',
#  '₹399',
#  '₹198',
#  '₹315',
#  '₹282',
#  '₹426',
#  '₹169',
#  '₹349',
#  '₹165',
#  '₹695',
#  '₹474',
#  '₹149',
#  '₹208',
#  '₹649',
#  '₹499',
#  '₹208',
#  '₹268',
#  '₹289',
#  '₹190',
#  '₹399',
#  '₹664',
#  '₹324',
#  '₹499',
#  '₹399',
#  '₹375',
#  '₹599',
#  '₹189',
#  '₹599',
#  '₹269',
#  '₹259',
#  '₹499',
#  '₹123',
#  '₹224',
#  '₹290',
#  '₹449',
#  '₹239',
#  '₹652',
#  '₹229',
#  '₹283',
#  '₹289',
#  '₹891']

# %%
#Extract the tag having the discount-titles

for page in range(0,3):
    discounts_tags=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']")

    
for i in discounts_tags:
    discounts=i.text
    discount.append(discounts)
driver.find_element_by_xpath("//a[@class='_1LKTO3']").click()
discount
# Out:
# ['86% off',
#  '85% off',
#  '77% off',
#  '85% off',
#  '75% off',
#  '83% off',
#  '66% off',
#  '86% off',
#  '87% off',
#  '77% off',
#  '78% off',
#  '83% off',
#  '55% off',
#  '80% off',
#  '83% off',
#  '73% off',
#  '77% off',
#  '80% off',
#  '83% off',
#  '86% off',
#  '87% off',
#  '13% off',
#  '75% off',
#  '85% off',
#  '79% off',
#  '27% off',
#  '70% off',
#  '82% off',
#  '84% off',
#  '77% off',
#  '80% off',
#  '72% off',
#  '55% off',
#  '67% off',
#  '80% off',
#  '80% off',
#  '77% off',
#  '33% off',
#  '72% off',
#  '40% off',
#  '73% off',
#  '87% off',
#  '26% off',
#  '86% off',
#  '69% off',
#  '77% off',
#  '33% off',
#  '37% off',
#  '37% off',
#  '79% off',
#  '80% off',
#  '80% off',
#  '80% off',
#  '86% off',
#  '77% off',
#  '73% off',
#  '85% off',
#  '33% off',
#  '80% off',
#  '69% off',
#  '33% off',
#  '81% off',
#  '74% off',
#  '31% off',
#  '83% off',
#  '45% off',
#  '70% off',
#  '74% off',
#  '77% off',
#  '25% off',
#  '82% off',
#  '83% off',
#  '57% off',
#  '85% off',
#  '88% off',
#  '73% off',
#  '86% off',
#  '77% off',
#  '85% off',
#  '85% off',
#  '84% off',
#  '50% off',
#  '66% off',
#  '77% off',
#  '33% off',
#  '37% off',
#  '37% off',
#  '79% off',
#  '80% off',
#  '80% off',
#  '80% off',
#  '86% off',
#  '77% off',
#  '73% off',
#  '33% off',
#  '80% off',
#  '69% off',
#  '33% off',
#  '81% off',
#  '31% off',
#  '83% off',
#  '45% off',
#  '74% off',
#  '77% off',
#  '25% off',
#  '82% off',
#  '83% off',
#  '85% off',
#  '88% off',
#  '73% off',
#  '77% off',
#  '85% off',
#  '85% off',
#  '84% off',
#  '50% off',
#  '85% off',
#  '75% off',
#  '83% off',
#  '86% off',
#  '87% off',
#  '77% off',
#  '78% off',
#  '83% off']

# %%
#Now we need to check the length of lists
print(len(Brand),len(Product_desc),len(price),len(discount))
# Out:
# 120 123 120 123

# %%
Sunglasses=pd.DataFrame({})
Sunglasses['Brand']=Brand[0:100]
Sunglasses['Product_desc']=Product_desc[0:100]
Sunglasses['price']=price[0:100]
Sunglasses['discount']=discount[0:100]

# %%
Sunglasses
# Out:
#                Brand                                       Product_desc price  \
# 0               hipe              UV Protection Aviator Sunglasses (54)  ₹199
# 1            Ayezent              UV Protection Aviator Sunglasses (58)  ₹282
# 2     ROZZETTA CRAFT    Gradient, UV Protection Aviator Sunglasses (58)  ₹499
# 3           Fastrack          UV Protection Rectangular Sunglasses (50)  ₹599
# 4           Fastrack  UV Protection, Night Vision, Gradient Retro Sq...  ₹499
# ..               ...                                                ...   ...
# 95  shah collections  UV Protection Retro Square Sunglasses (Free Size)  ₹268
# 96     Online Mantra       UV Protection Aviator Sunglasses (Free Size)  ₹289
# 97          Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹190
# 98    kingsunglasses  Gradient, UV Protection Wayfarer Sunglasses (F...  ₹399
# 99         ROYAL SON  UV Protection, Gradient Rectangular Sunglasses...  ₹664
#
#    discount
# 0   86% off
# 1   85% off
# 2   77% off
# 3   85% off
# 4   75% off
# ..      ...
# 95  80% off
# 96  69% off
# 97  33% off
# 98  81% off
# 99  31% off
#
# [100 rows x 4 columns]
